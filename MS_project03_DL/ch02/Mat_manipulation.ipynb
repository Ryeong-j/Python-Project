# %%
import numpy as np

# %%
A = np.array([1,2,3,4])
print(A)
print(np.ndim(A))
print(A.shape)
# Out:
# [1 2 3 4]
# 1
# (4,)

# %%
B = np.array([[1,2], [3,4], [5,6]])
print(B)
print(np.ndim(B))
print(B.shape)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# 2
# (3, 2)

# %%
X = np.array([1,2])
X.shape
# Out:
# (2,)
