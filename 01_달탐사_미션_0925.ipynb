# %%
import pandas as pd

# %%
rock_samples = pd.read_csv("data/rocksamples.csv")

# %%
rock_samples.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2229 entries, 0 to 2228
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            2229 non-null   int64
#  1   Mission       2229 non-null   object
#  2   Type          2229 non-null   object
#  3   Subtype       2226 non-null   object
#  4   Weight (g)    2229 non-null   float64
#  5   Pristine (%)  2229 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 104.6+ KB

# %%
rock_samples.describe()
# Out:
#                  ID    Weight (g)  Pristine (%)
# count   2229.000000   2229.000000   2229.000000
# mean   52058.432032    168.253024     84.512764
# std    26207.651471    637.286458     22.057299
# min    10001.000000      0.000000      0.000000
# 25%    15437.000000      3.000000     80.010000
# 50%    65527.000000     10.200000     92.300000
# 75%    72142.000000     93.490000     98.140000
# max    79537.000000  11729.000000    180.000000

# %%
rock_samples.head()
# Out:
#       ID   Mission    Type   Subtype  Weight (g)  Pristine (%)
# 0  10001  Apollo11    Soil  Unsieved       125.8         88.36
# 1  10002  Apollo11    Soil  Unsieved      5629.0         93.73
# 2  10003  Apollo11  Basalt  Ilmenite       213.0         65.56
# 3  10004  Apollo11    Core  Unsieved        44.8         71.76
# 4  10005  Apollo11    Core  Unsieved        53.4         40.31

# %%
rock_samples.sample(9) #랜덤으로 샘플 뽑아줌
# Out:
#          ID   Mission     Type     Subtype  Weight (g)  Pristine (%)
# 1443  68841  Apollo16     Soil        <1mm      266.60         93.27
# 1571  71048  Apollo17   Basalt    Ilmenite        2.46         73.55
# 565   15470  Apollo15     Soil    Unsieved       82.20         97.82
# 1586  71085  Apollo17   Basalt    Ilmenite        3.40         87.60
# 1933  76036  Apollo17  Breccia  ImpactMelt        3.95        100.00
# 129   12070  Apollo12     Soil    Unsieved     1102.00         80.24
# 725   60051  Apollo16     Soil        <1mm      195.30         89.25
# 210   14175  Apollo14  Breccia  Fragmental        7.48         92.91
# 125   12062  Apollo12   Basalt    Ilmenite      738.70         97.52

# %%
rock_samples.shape
# Out:
# (2229, 6)

# %%
rock_samples.columns
# Out:
# Index(['ID', 'Mission', 'Type', 'Subtype', 'Weight (g)', 'Pristine (%)'], dtype='object')

# %%
rock_samples.dtypes
# Out:
# ID                int64
# Mission          object
# Type             object
# Subtype          object
# Weight (g)      float64
# Pristine (%)    float64
# dtype: object

# %%
rock_samples.isnull().sum()
# Out:
# ID              0
# Mission         0
# Type            0
# Subtype         3
# Weight (g)      0
# Pristine (%)    0
# dtype: int64

# %%
rock_samples[rock_samples['Subtype'].isnull()]
# Out:
#          ID   Mission     Type Subtype  Weight (g)  Pristine (%)
# 89    12023  Apollo12  Special     NaN      407.90         66.89
# 355   15014  Apollo15  Special     NaN      333.20        100.00
# 1513  70149  Apollo17   Basalt     NaN        0.95          0.00

# %%
rock_samples['Type'].unique()
# Out:
# array(['Soil', 'Basalt', 'Core', 'Breccia', 'Special', 'Crustal'],
#       dtype=object)

# %%
rock_samples['Subtype'].unique()
# Out:
# array(['Unsieved', 'Ilmenite', 'Regolith', 'Cristobalite', 'Olivine',
#        'Pigeonite', 'Fragmental', nan, 'Feldspathic', 'Unclassified',
#        '2-4mm', '1-2mm', '<1mm', '4-10mm', '>10mm', 'ImpactMelt', 'KREEP',
#        'Glass', 'Agglomerate', 'Unstudied', 'Cataclastic', 'Clod',
#        'Anorthosite', 'unsieved', 'Plagioclase', 'fragmental',
#        'unstudied', 'notstudied', 'Cataclasite', 'Troctolite', 'Norite',
#        'Pristine'], dtype=object)

# %%
rock_samples['Subtype'].value_counts()
# Out:
# Subtype
# ImpactMelt      393
# Unsieved        271
# Regolith        248
# Fragmental      208
# Ilmenite        184
# <1mm            147
# 1-2mm           145
# 4-10mm          145
# 2-4mm           145
# Olivine         115
# Anorthosite      41
# Pigeonite        37
# Unclassified     24
# fragmental       21
# unsieved         17
# Clod             17
# Cataclasite      16
# Agglomerate      10
# unstudied        10
# Feldspathic       8
# Glass             7
# Norite            4
# KREEP             3
# Cataclastic       3
# Cristobalite      1
# >10mm             1
# Unstudied         1
# notstudied        1
# Plagioclase       1
# Troctolite        1
# Pristine          1
# Name: count, dtype: int64

# %% [markdown]
# ### type, subtype로 분류해보기
# - size()는 보기 편하게 해줌

# %%
rock_samples.groupby(['Type', 'Subtype']).size()
# Out:
# Type     Subtype
# Basalt   Cristobalite      1
#          Feldspathic       7
#          Ilmenite        184
#          KREEP             3
#          Olivine         115
#          Pigeonite        37
#          Plagioclase       1
#          Unclassified      2
# Breccia  Agglomerate      10
#          Anorthosite      21
#          Clod             17
#          Feldspathic       1
#          Fragmental      207
#          Glass             7
#          ImpactMelt      393
#          Regolith        248
#          Unclassified     22
#          Unstudied         1
#          fragmental       21
#          notstudied        1
#          unstudied        10
# Core     Unsieved         41
#          unsieved         15
# Crustal  Anorthosite      20
#          Cataclasite      16
#          Cataclastic       3
#          Fragmental        1
#          Norite            4
#          Pristine          1
#          Troctolite        1
# Soil     1-2mm           145
# ...

# %%
rock_samples['Weight (kg)'] = rock_samples['Weight (g)'] /1000
#rock_samples['Weight (g)'] = rock_samples['Weight (g)'].apply(lambda x: x * 0.001)
#rock.samples['Weight (g)'].rename(columns={'Weight (g)':'Weight (kg)'})

# %% [markdown]
# #### rock_samples.columns=[기존 df와 길이가 일치하는 열 이름 리스트 만들어서 넣기]

# %%
rock_samples
# Out:
#          ID   Mission     Type   Subtype  Weight (g)  Pristine (%)  \
# 0     10001  Apollo11     Soil  Unsieved      125.80         88.36
# 1     10002  Apollo11     Soil  Unsieved     5629.00         93.73
# 2     10003  Apollo11   Basalt  Ilmenite      213.00         65.56
# 3     10004  Apollo11     Core  Unsieved       44.80         71.76
# 4     10005  Apollo11     Core  Unsieved       53.40         40.31
# ...     ...       ...      ...       ...         ...           ...
# 2224  79528  Apollo17  Breccia  Regolith        2.38        100.00
# 2225  79529  Apollo17  Breccia  Regolith        1.84        100.00
# 2226  79535  Apollo17  Breccia  Regolith        1.69        100.00
# 2227  79536  Apollo17  Breccia  Regolith        1.66        100.00
# 2228  79537  Apollo17  Breccia  Regolith        1.05        100.00
#
#       Weight (kg)
# 0         0.12580
# 1         5.62900
# 2         0.21300
# 3         0.04480
# 4         0.05340
# ...           ...
# 2224      0.00238
# ...

# %%
rock_samples.drop(columns='Weight (g)')
# Out:
#          ID   Mission     Type   Subtype  Pristine (%)  Weight (kg)
# 0     10001  Apollo11     Soil  Unsieved         88.36      0.12580
# 1     10002  Apollo11     Soil  Unsieved         93.73      5.62900
# 2     10003  Apollo11   Basalt  Ilmenite         65.56      0.21300
# 3     10004  Apollo11     Core  Unsieved         71.76      0.04480
# 4     10005  Apollo11     Core  Unsieved         40.31      0.05340
# ...     ...       ...      ...       ...           ...          ...
# 2224  79528  Apollo17  Breccia  Regolith        100.00      0.00238
# 2225  79529  Apollo17  Breccia  Regolith        100.00      0.00184
# 2226  79535  Apollo17  Breccia  Regolith        100.00      0.00169
# 2227  79536  Apollo17  Breccia  Regolith        100.00      0.00166
# 2228  79537  Apollo17  Breccia  Regolith        100.00      0.00105
#
# [2229 rows x 6 columns]

# %%
mission= pd.DataFrame()

# %%
mission["Mission"]=rock_samples["Mission"].unique()

# %%
mission
# Out:
#     Mission
# 0  Apollo11
# 1  Apollo12
# 2  Apollo14
# 3  Apollo15
# 4  Apollo16
# 5  Apollo17

# %% [markdown]
# ## 아폴로 임무별 샘플 중량 총합

# %%
a=rock_samples.groupby('Mission')['Weight (kg)'].sum()

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.values
# Out:
# array([ 21.55424,  34.34238,  41.83363,  75.3991 ,  92.46262, 109.44402])

# %%
mission['Weight (kg)'] = a.values

# %%
mission=mission.drop(columns='total_Weight(kg)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 mission=mission.drop(columns='total_Weight(kg)')
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %%
mission=mission.rename(columns={'Weight (kg)':'Sample_Weight (kg)'})

# %% [markdown]
# ### 임무간 중량 차이 구하기

# %%
mission['Weight_diff']=mission['Sample_Weight (kg)'].diff()

# %%
misson=mission['Weight_diff'].fillna(value=0, inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4336\4150101196.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   misson=mission['Weight_diff'].fillna(value=0, inplace=True)

# %%
mission
# Out:
#     Mission  Sample_Weight (kg)  Weight_diff
# 0  Apollo11            21.55424      0.00000
# 1  Apollo12            34.34238     12.78814
# 2  Apollo14            41.83363      7.49125
# 3  Apollo15            75.39910     33.56547
# 4  Apollo16            92.46262     17.06352
# 5  Apollo17           109.44402     16.98140

# %% [markdown]
# ### 달 모듈의 이름, 중량 컬럼을 mission에 추가
# - 달 모듈과 명령 모듈이 있고 이 두가지를 일컫어 승무원 어쩌구라고 한다.

# %%
달모듈이름 = ['Eagle (LM-5)', 'Intrepid (LM-6)', 'Antares (LM-8)', 'Falcon (LM-10)', 'Orion (LM-11)', 'Challenger (LM-12)']
달모듈중량 = [15103, 15235, 15264, 16430, 16445, 16456]

# %%
mission['Lunar module (LM)'] = 달모듈이름
mission['LM mass (kg)'] = 달모듈중량
mission
# Out:
#     Mission  Sample_Weight (kg)  Weight_diff   Lunar module (LM)  LM mass (kg)
# 0  Apollo11            21.55424      0.00000        Eagle (LM-5)         15103
# 1  Apollo12            34.34238     12.78814     Intrepid (LM-6)         15235
# 2  Apollo14            41.83363      7.49125      Antares (LM-8)         15264
# 3  Apollo15            75.39910     33.56547      Falcon (LM-10)         16430
# 4  Apollo16            92.46262     17.06352       Orion (LM-11)         16445
# 5  Apollo17           109.44402     16.98140  Challenger (LM-12)         16456

# %%
mission['LM mass diff']=mission['LM mass (kg)'].diff()

# %%
mission['LM mass diff'].fillna(value=0, inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4336\1992362754.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   mission['LM mass diff'].fillna(value=0, inplace=True)

# %%
mission
# Out:
#     Mission  Sample_Weight (kg)  Weight_diff   Lunar module (LM)  \
# 0  Apollo11            21.55424      0.00000        Eagle (LM-5)
# 1  Apollo12            34.34238     12.78814     Intrepid (LM-6)
# 2  Apollo14            41.83363      7.49125      Antares (LM-8)
# 3  Apollo15            75.39910     33.56547      Falcon (LM-10)
# 4  Apollo16            92.46262     17.06352       Orion (LM-11)
# 5  Apollo17           109.44402     16.98140  Challenger (LM-12)
#
#    LM mass (kg)  LM mass diff
# 0         15103           0.0
# 1         15235         132.0
# 2         15264          29.0
# 3         16430        1166.0
# 4         16445          15.0
# 5         16456          11.0

# %%
명령모듈이름 = ['Columbia (CSM-107]', 'Yankee Clipper (CM-100])', 'Kitty Hawk (CM-110)', 'Endeavor (CM-112)', 'Casper (CM-113)', 'America (CM-114)']
명령모듈중량 = [5560, 5609, 5758, 5875, 5840, 5960]

# %%
mission['Command Module (CM)'] = 명령모듈이름
mission['CM Mass (kg)'] = 명령모듈중량

# %%
mission['CM Mass diff']=mission['CM Mass (kg)'].diff()

# %%
mission['CM Mass diff'].fillna(value = 0, inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4336\2128624598.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   mission['CM Mass diff'].fillna(value = 0, inplace=True)

# %%
mission['Total weight (kg)']=mission['LM mass (kg)']+mission['CM Mass (kg)']

# %%
mission['Total weight diff']= mission['Total weight (kg)'].diff()
mission['Total weight diff'].fillna(value=0, inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4336\3435717993.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   mission['Total weight diff'].fillna(value=0, inplace=True)

# %%
mission
# Out:
#     Mission  Sample_Weight (kg)  Weight_diff   Lunar module (LM)  \
# 0  Apollo11            21.55424      0.00000        Eagle (LM-5)
# 1  Apollo12            34.34238     12.78814     Intrepid (LM-6)
# 2  Apollo14            41.83363      7.49125      Antares (LM-8)
# 3  Apollo15            75.39910     33.56547      Falcon (LM-10)
# 4  Apollo16            92.46262     17.06352       Orion (LM-11)
# 5  Apollo17           109.44402     16.98140  Challenger (LM-12)
#
#    LM mass (kg)  LM mass diff       Command Module (CM)  CM Mass (kg)  \
# 0         15103           0.0        Columbia (CSM-107]          5560
# 1         15235         132.0  Yankee Clipper (CM-100])          5609
# 2         15264          29.0       Kitty Hawk (CM-110)          5758
# 3         16430        1166.0         Endeavor (CM-112)          5875
# 4         16445          15.0           Casper (CM-113)          5840
# 5         16456          11.0          America (CM-114)          5960
#
# ...

# %%
saturnVPayload = 435000

# 페이로드에서 승무원 영역이 차지하는 비율
mission['Crewed area : Payload'] = mission['Total weight (kg)']/saturnVPayload
mission
# Out:
#     Mission  Sample_Weight (kg)  Weight_diff   Lunar module (LM)  \
# 0  Apollo11            21.55424      0.00000        Eagle (LM-5)
# 1  Apollo12            34.34238     12.78814     Intrepid (LM-6)
# 2  Apollo14            41.83363      7.49125      Antares (LM-8)
# 3  Apollo15            75.39910     33.56547      Falcon (LM-10)
# 4  Apollo16            92.46262     17.06352       Orion (LM-11)
# 5  Apollo17           109.44402     16.98140  Challenger (LM-12)
#
#    LM mass (kg)  LM mass diff       Command Module (CM)  CM Mass (kg)  \
# 0         15103           0.0        Columbia (CSM-107]          5560
# 1         15235         132.0  Yankee Clipper (CM-100])          5609
# 2         15264          29.0       Kitty Hawk (CM-110)          5758
# 3         16430        1166.0         Endeavor (CM-112)          5875
# 4         16445          15.0           Casper (CM-113)          5840
# 5         16456          11.0          America (CM-114)          5960
#
# ...

# %%
# 승무원 영역에서 암석 샘플이 차지하는 비율
temp = mission['Sample_Weight (kg)'] / mission['Total weight (kg)']
temp
# Out:
# 0    0.001043
# 1    0.001648
# 2    0.001990
# 3    0.003380
# 4    0.004149
# 5    0.004882
# dtype: float64

# %%
mission['Sample : Crewed area'] = temp
mission
# Out:
#     Mission  Sample_Weight (kg)  Weight_diff   Lunar module (LM)  \
# 0  Apollo11            21.55424      0.00000        Eagle (LM-5)
# 1  Apollo12            34.34238     12.78814     Intrepid (LM-6)
# 2  Apollo14            41.83363      7.49125      Antares (LM-8)
# 3  Apollo15            75.39910     33.56547      Falcon (LM-10)
# 4  Apollo16            92.46262     17.06352       Orion (LM-11)
# 5  Apollo17           109.44402     16.98140  Challenger (LM-12)
#
#    LM mass (kg)  LM mass diff       Command Module (CM)  CM Mass (kg)  \
# 0         15103           0.0        Columbia (CSM-107]          5560
# 1         15235         132.0  Yankee Clipper (CM-100])          5609
# 2         15264          29.0       Kitty Hawk (CM-110)          5758
# 3         16430        1166.0         Endeavor (CM-112)          5875
# 4         16445          15.0           Casper (CM-113)          5840
# 5         16456          11.0          America (CM-114)          5960
#
# ...

# %%
# 페이로드에서 샘플이 차지하는 비율
mission['Sample : Payload'] = mission['Sample_Weight (kg)'] / saturnVPayload

# %%
mission
# Out:
#     Mission  Sample_Weight (kg)  Weight_diff   Lunar module (LM)  \
# 0  Apollo11            21.55424      0.00000        Eagle (LM-5)
# 1  Apollo12            34.34238     12.78814     Intrepid (LM-6)
# 2  Apollo14            41.83363      7.49125      Antares (LM-8)
# 3  Apollo15            75.39910     33.56547      Falcon (LM-10)
# 4  Apollo16            92.46262     17.06352       Orion (LM-11)
# 5  Apollo17           109.44402     16.98140  Challenger (LM-12)
#
#    LM mass (kg)  LM mass diff       Command Module (CM)  CM Mass (kg)  \
# 0         15103           0.0        Columbia (CSM-107]          5560
# 1         15235         132.0  Yankee Clipper (CM-100])          5609
# 2         15264          29.0       Kitty Hawk (CM-110)          5758
# 3         16430        1166.0         Endeavor (CM-112)          5875
# 4         16445          15.0           Casper (CM-113)          5840
# 5         16456          11.0          America (CM-114)          5960
#
# ...

# %% [markdown]
# ### 아르테미스 미션 프레임 만들기

# %%
artemis_crewedArea = 26520

artemis_dict = {'Mission' : ['artemis1', 'artemis1b', 'artemis2'],
                'Total weight (kg)' : [artemis_crewedArea, artemis_crewedArea, artemis_crewedArea],
                'Payload (kg)' : [26988, 37965, 42955]
               }

#딕셔너리를 데이터 프레임으로 저장하기
artemis_mission = pd.DataFrame(artemis_dict)

# %%
artemis_mission
# Out:
#      Mission  Total weight (kg)  Payload (kg)
# 0   artemis1              26520         26988
# 1  artemis1b              26520         37965
# 2   artemis2              26520         42955

# %%
cp=mission['Crewed area : Payload'].mean()
sp=mission['Sample : Payload'].mean()
sc=mission['Sample : Crewed area'].mean()

# %%
cp, sp, sc
# Out:
# (np.float64(0.04963026819923372),
#  np.float64(0.00014369195019157087),
#  np.float64(0.002848764392685611))

# %%
artemis_mission['Sample weight from total(kg)'] = artemis_mission['Total weight (kg)'] * sc
artemis_mission['Sample weight from payload(kg)'] = artemis_mission['Payload (kg)']*10 * sp

# %%
artemis_mission['Estimated sample weight'] =  (artemis_mission['Sample weight from payload(kg)']+artemis_mission['Sample weight from total(kg)'])/2

# %%
artemis_mission
# Out:
#      Mission  Total weight (kg)  Payload (kg)  Sample weight from totaln(kg)  \
# 0   artemis1              26520         26988                      75.549232
# 1  artemis1b              26520         37965                      75.549232
# 2   artemis2              26520         42955                      75.549232
#
#    Sample weight from payload(kg)  Sample weight from total(kg)  \
# 0                       38.779584                     75.549232
# 1                       54.552649                     75.549232
# 2                       61.722877                     75.549232
#
#    Estimated sample weight
# 0                57.164408
# 1                65.050940
# 2                68.636054

# %% [markdown]
# ## 아르테미스 임무에서 가져올 암석 종류 구하기

# %%
rock_samples.head()
# Out:
#       ID   Mission    Type   Subtype  Weight (g)  Pristine (%)  Weight (kg)
# 0  10001  Apollo11    Soil  Unsieved       125.8         88.36       0.1258
# 1  10002  Apollo11    Soil  Unsieved      5629.0         93.73       5.6290
# 2  10003  Apollo11  Basalt  Ilmenite       213.0         65.56       0.2130
# 3  10004  Apollo11    Core  Unsieved        44.8         71.76       0.0448
# 4  10005  Apollo11    Core  Unsieved        53.4         40.31       0.0534

# %%
rock_samples['Remaining (kg)']=(rock_samples['Weight (kg)']*rock_samples['Pristine (%)'])*0.001

# %%
rock_samples.drop(columns='Weight (g)', inplace = True)

# %%
rock_samples
# Out:
#          ID   Mission     Type   Subtype  Pristine (%)  Weight (kg)  \
# 0     10001  Apollo11     Soil  Unsieved         88.36      0.12580
# 1     10002  Apollo11     Soil  Unsieved         93.73      5.62900
# 2     10003  Apollo11   Basalt  Ilmenite         65.56      0.21300
# 3     10004  Apollo11     Core  Unsieved         71.76      0.04480
# 4     10005  Apollo11     Core  Unsieved         40.31      0.05340
# ...     ...       ...      ...       ...           ...          ...
# 2224  79528  Apollo17  Breccia  Regolith        100.00      0.00238
# 2225  79529  Apollo17  Breccia  Regolith        100.00      0.00184
# 2226  79535  Apollo17  Breccia  Regolith        100.00      0.00169
# 2227  79536  Apollo17  Breccia  Regolith        100.00      0.00166
# 2228  79537  Apollo17  Breccia  Regolith        100.00      0.00105
#
#       Remaining (kg)
# 0           0.011116
# 1           0.527606
# 2           0.013964
# 3           0.003215
# 4           0.002153
# ...

# %%
low_samples = rock_samples[(rock_samples['Weight (kg)'] >= 0.16) & (rock_samples['Pristine (%)'] <= 50)]

# %%
low_samples.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, 11 to 2183
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              27 non-null     int64
#  1   Mission         27 non-null     object
#  2   Type            27 non-null     object
#  3   Subtype         27 non-null     object
#  4   Pristine (%)    27 non-null     float64
#  5   Weight (kg)     27 non-null     float64
#  6   Remaining (kg)  27 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.7+ KB

# %%
low_samples['Type'].value_counts()
# Out:
# Type
# Basalt     14
# Breccia     8
# Soil        4
# Core        1
# Name: count, dtype: int64

# %%
needed_sample=low_samples[low_samples['Type'].isin(['Basalt', 'Breccia'])]

# %%
needed_sample
# Out:
#          ID   Mission     Type      Subtype  Pristine (%)  Weight (kg)  \
# 11    10017  Apollo11   Basalt     Ilmenite         43.71       0.9730
# 14    10020  Apollo11   Basalt     Ilmenite         27.88       0.4250
# 15    10021  Apollo11  Breccia     Regolith         30.21       0.2500
# 29    10045  Apollo11   Basalt      Olivine         12.13       0.1850
# 37    10057  Apollo11   Basalt     Ilmenite         35.15       0.9190
# 39    10059  Apollo11  Breccia     Regolith         36.94       0.1880
# 52    10072  Apollo11   Basalt     Ilmenite         15.22       0.4470
# 68    12002  Apollo12   Basalt      Olivine         49.04       1.5300
# 72    12006  Apollo12   Basalt      Olivine          0.53       0.2064
# 113   12047  Apollo12   Basalt     Ilmenite         33.70       0.1930
# 118   12053  Apollo12   Basalt    Pigeonite         46.43       0.8790
# 120   12055  Apollo12   Basalt    Pigeonite         26.00       0.9120
# ...

# %%
rock_samples['Type'].value_counts()
# Out:
# Type
# Breccia    959
# Soil       813
# Basalt     351
# Core        56
# Crustal     46
# Special      4
# Name: count, dtype: int64

# %%
crustal = rock_samples[rock_samples['Type']=='Crustal']

# %%
needed_sample = pd.concat([needed_sample, crustal])

# %% [markdown]
# ### neeeded samples overview 만들기
# - needed samples : 어떤 암석 종류를 체취하겠냐를 정함
# - basalt, breccia, crustal

# %%
overview = needed_sample.groupby('Type')["Weight (kg)"].sum().reset_index()

# %%
overview
# Out:
#       Type  Weight (kg)
# 0   Basalt     17.42340
# 1  Breccia     10.11850
# 2  Crustal      4.74469

# %%
overview.rename(columns = {'Weight (kg)':'Total weight (kg)'},inplace = True)

# %%
# reset.index() -> 인덱스 초기화해줌
temp = needed_sample.groupby('Type')["Weight (kg)"].mean().reset_index()

# %%
# Out:
#       Type  Weight (kg)
# 0   Basalt     1.244529
# 1  Breccia     1.264813
# 2  Crustal     0.103145

# %%
overview= pd.merge(overview, temp, on = 'Type')

# %%
overview
# Out:
#       Type  Total weight (kg)  Weight (kg)
# 0   Basalt           17.42340     1.244529
# 1  Breccia           10.11850     1.264813
# 2  Crustal            4.74469     0.103145

# %%
overview.rename(columns = {'Weight (kg)':'Average weight (kg)'},inplace = True)

# %%
overview
# Out:
#       Type  Total weight (kg)  Average weight (kg)
# 0   Basalt           17.42340             1.244529
# 1  Breccia           10.11850             1.264813
# 2  Crustal            4.74469             0.103145

# %%
temp = rock_samples.groupby('Type')['ID'].count().reset_index()
# ID는 아무런 영향을 미치지 않기 때문에 넣은거임(그냥 타입 별로 수를 세야해서)

# %%
overview= pd.merge(overview, temp, on='Type')

# %%
overview
# Out:
#       Type  Total weight (kg)  Average weight (kg)   ID
# 0   Basalt           17.42340             1.244529  351
# 1  Breccia           10.11850             1.264813  959
# 2  Crustal            4.74469             0.103145   46

# %%
overview.rename(columns={'ID':'Number of samples'}, inplace=True)

# %%
overview
# Out:
#       Type  Total weight (kg)  Average weight (kg)  Number of samples
# 0   Basalt           17.42340             1.244529                351
# 1  Breccia           10.11850             1.264813                959
# 2  Crustal            4.74469             0.103145                 46

# %%
temp = overview['Number of samples'].sum()

# %%
overview['Percentage']=overview["Number of samples"]/temp

# %%
overview
# Out:
#       Type  Total weight (kg)  Average weight (kg)  Number of samples  \
# 0   Basalt           17.42340             1.244529                351
# 1  Breccia           10.11850             1.264813                959
# 2  Crustal            4.74469             0.103145                 46
#
#    Percentage
# 0    0.258850
# 1    0.707227
# 2    0.033923

# %% [markdown]
# ## 수집할 암석 별 무게

# %%
temp=artemis_mission['Estimated sample weight'].mean()

# %%
overview['Weight to Collect']=overview['Percentage']*temp

# %%
overview
# Out:
#       Type  Total weight (kg)  Average weight (kg)  Number of samples  \
# 0   Basalt           17.42340             1.244529                351
# 1  Breccia           10.11850             1.264813                959
# 2  Crustal            4.74469             0.103145                 46
#
#    Percentage  Weight to Collect
# 0    0.258850          16.467267
# 1    0.707227          44.991764
# 2    0.033923           2.158103

# %% [markdown]
# ## 수집할 암석 별 개수

# %%
overview['Rock to collect'] = overview['Weight to Collect']/overview['Average weight (kg)']

# %%
overview
# Out:
#       Type  Total weight (kg)  Average weight (kg)  Number of samples  \
# 0   Basalt           17.42340             1.244529                351
# 1  Breccia           10.11850             1.264813                959
# 2  Crustal            4.74469             0.103145                 46
#
#    Percentage  Weight to Collect  Rock to collect
# 0    0.258850          16.467267        13.231731
# 1    0.707227          44.991764        35.571884
# 2    0.033923           2.158103        20.922917

# %% [markdown]
# ## 결론
#
# - 암석을 실을 수 있는 최대 무게는 약 63kg이므로 암석 별 무게를 고려하여 최대 무게를 넘어가지 않도록 암석 별로 채굴할 개수를 구했다.
#     - 암석 채굴 비율
#         - Basalt: 25.9%
#         - Breccia: 70.7%
#         - Crustal: 2.4%
#     - 암석 평균 무게
#         - Basalt: 1.25kg
#         - Breccia: 1.26kg
#         - Crustal: 0.1kg
#     - 암석 채굴 개수
#         - Basalt: 13개
#         - Breccia: 36개
#         - Crustal: 21개
# - Basalt와 Breccia는 채굴량이 많고, 사용량 또한 많기 때문에 다음 미션에서 더 채굴해와야할 필요가 있다.
# - Crustal 같은 경우에는 채굴량 자체는 적으나 그 이유가 희귀하기 때문이고 사용량 또한 적지 않으므로 다음 미션에서 채굴해와야한다.
