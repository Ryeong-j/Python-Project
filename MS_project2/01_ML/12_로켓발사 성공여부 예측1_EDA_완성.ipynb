# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %% [markdown]
# #### 데이터 준비

# %%
df = pd.read_csv('data/RocketLaunchDataCompleted.csv', encoding='cp949')
df.head()
# Out:
#         Name       Date Time (East Coast)        Location Crewed or Uncrewed  \
# 0        NaN  04-Dec-58               NaN  Cape Canaveral                NaN
# 1        NaN  05-Dec-58               NaN  Cape Canaveral                NaN
# 2  Pioneer 3  06-Dec-58              1:45  Cape Canaveral           Uncrewed
# 3        NaN  07-Dec-58               NaN  Cape Canaveral                NaN
# 4        NaN  08-Dec-58               NaN  Cape Canaveral                NaN
#
#   Launched?  High Temp  Low Temp  Ave Temp  Temp at Launch Time  ...  \
# 0       NaN       75.0      68.0     71.00                  NaN  ...
# 1       NaN       78.0      70.0     73.39                  NaN  ...
# 2         Y       73.0       0.0     60.21                 62.0  ...
# 3       NaN       76.0      57.0     66.04                  NaN  ...
# 4       NaN       79.0      60.0     70.52                  NaN  ...
#
#    Max Wind Speed  Visibility  Wind Speed at Launch Time  \
# 0            16.0        15.0                        NaN
# 1            14.0        10.0                        NaN
# 2            15.0        10.0                       11.0
# 3            10.0        10.0                        NaN
# 4            12.0        10.0                        NaN
#
#    Hist Ave Max Wind Speed  Hist Ave Visibility Sea Level Pressure  \
# 0                      NaN                  NaN              30.22
# 1                      NaN                  NaN               30.2
# 2                      NaN                  NaN              30.25
# 3                      NaN                  NaN              30.28
# 4                      NaN                  NaN              30.23
#
#    Hist Ave Sea Level Pressure  Day Length      Condition  Notes
# 0                          NaN       10:26         Cloudy    NaN
# 1                          NaN       10:26         Cloudy    NaN
# 2                          NaN       10:25         Cloudy    NaN
# 3                          NaN       10:25  Partly Cloudy    NaN
# 4                          NaN       12:24  Partly Cloudy    NaN
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Name                          60 non-null     object
#  1   Date                          300 non-null    object
#  2   Time (East Coast)             59 non-null     object
#  3   Location                      300 non-null    object
#  4   Crewed or Uncrewed            60 non-null     object
#  5   Launched?                     60 non-null     object
#  6   High Temp                     299 non-null    float64
#  7   Low Temp                      299 non-null    float64
#  8   Ave Temp                      299 non-null    float64
#  9   Temp at Launch Time           59 non-null     float64
#  10  Hist High Temp                299 non-null    float64
#  11  Hist Low Temp                 299 non-null    float64
#  12  Hist Ave Temp                 299 non-null    float64
#  13  Percipitation at Launch Time  299 non-null    float64
#  14  Hist Ave Percipitation        299 non-null    float64
#  15  Wind Direction                299 non-null    object
#  16  Max Wind Speed                299 non-null    float64
#  17  Visibility                    299 non-null    float64
#  18  Wind Speed at Launch Time     59 non-null     float64
#  19  Hist Ave Max Wind Speed       0 non-null      float64
#  20  Hist Ave Visibility           0 non-null      float64
#  21  Sea Level Pressure            299 non-null    object
#  22  Hist Ave Sea Level Pressure   0 non-null      float64
#  23  Day Length                    298 non-null    object
#  24  Condition                     298 non-null    object
#  25  Notes                         3 non-null      object
# dtypes: float64(15), object(11)
# memory usage: 61.1+ KB

# %% [markdown]
# #### 결측치 확인

# %%
df.isnull().mean().sort_values(ascending=False)
# Out:
# Hist Ave Sea Level Pressure     1.000000
# Hist Ave Visibility             1.000000
# Hist Ave Max Wind Speed         1.000000
# Notes                           0.990000
# Temp at Launch Time             0.803333
# Time (East Coast)               0.803333
# Wind Speed at Launch Time       0.803333
# Name                            0.800000
# Crewed or Uncrewed              0.800000
# Launched?                       0.800000
# Condition                       0.006667
# Day Length                      0.006667
# Ave Temp                        0.003333
# Low Temp                        0.003333
# Sea Level Pressure              0.003333
# High Temp                       0.003333
# Visibility                      0.003333
# Max Wind Speed                  0.003333
# Wind Direction                  0.003333
# Hist Ave Percipitation          0.003333
# Hist Ave Temp                   0.003333
# Hist Low Temp                   0.003333
# Hist High Temp                  0.003333
# Percipitation at Launch Time    0.003333
# Date                            0.000000
# Location                        0.000000
# dtype: float64

# %%
# !pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from missingno) (3.8.0)
# Requirement already satisfied: scipy in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from missingno) (1.11.4)
# Requirement already satisfied: seaborn in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from missingno) (0.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from seaborn->missingno) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2
# [notice] A new release of pip is available: 23.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting missingno
#   Using cached missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from missingno) (3.8.0)
# Requirement already satisfied: scipy in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from missingno) (1.11.4)
# Requirement already satisfied: seaborn in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from missingno) (0.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from seaborn->missingno) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\babie\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Using cached missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2
# [notice] A new release of pip is available: 23.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import missingno
plt.figure(figsize=(10,4))
missingno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# ### 결측치 처리

# %% [markdown]
# #### 결측치 채우기

# %%
# ----------------------------------------------------------------------
#   Crewed or Uncrewed  -> Uncrewed
#   Launched?           -> N
#   Wind Direction      -> Unknown
#   Condition           -> Fail
# ----------------------------------------------------------------------
fill_cols = {
    'Crewed or Uncrewed':'Uncrewed',
    'Launched?':'N',
    'Wind Direction':'Unknown',
    'Condition':'Fail'
}
df = df.fillna(fill_cols)

# %% [markdown]
# #### 사용하지 않을 컬럼 삭제

# %%
# ----------------------------------------------------------------------
# 전체 누락
#    -  Hist Ave Sea Level Pressure, Hist Ave Visibility, Hist Ave Max Wind Speed
# 관련도 낮음        
#    - Name, Date, Time (East Coast), Location
#    - Day Length, Notes, Sea Level Pressure
# ----------------------------------------------------------------------
drop_cols = ['Hist Ave Sea Level Pressure', 
            'Hist Ave Visibility', 
            'Hist Ave Max Wind Speed',
            'Name',
            'Date',
            'Time (East Coast)',
            'Location',
            'Day Length',
            'Notes',
            'Sea Level Pressure']

df = df.drop(drop_cols, axis=1)

# %% [markdown]
# ### 결측치 삭제

# %%
df.isnull().mean()
# Out:
# Crewed or Uncrewed              0.000000
# Launched?                       0.000000
# High Temp                       0.003333
# Low Temp                        0.003333
# Ave Temp                        0.003333
# Temp at Launch Time             0.803333
# Hist High Temp                  0.003333
# Hist Low Temp                   0.003333
# Hist Ave Temp                   0.003333
# Percipitation at Launch Time    0.003333
# Hist Ave Percipitation          0.003333
# Wind Direction                  0.000000
# Max Wind Speed                  0.003333
# Visibility                      0.003333
# Wind Speed at Launch Time       0.803333
# Condition                       0.000000
# dtype: float64

# %%
# -----------------
# 결측치가 70% 이상인 컬럼 삭제
# -----------------
del_cols = df.loc[:, df.isnull().mean()>0.7].columns
df = df.drop(del_cols, axis=1)

# %%
# ----------------------------------------------------------------------
#   그 외 누락값         -> 0
# ----------------------------------------------------------------------
df = df.fillna(0)

# %% [markdown]
# ### 타겟 인코딩

# %%
df['target'] = df['Launched?'].map({"Y":1, "N":0})

# %% [markdown]
# ### 변수 유형

# %%
cat_cols = df.select_dtypes(include='object').drop(['Launched?'],axis=1).columns
num_cols = df.select_dtypes(include='number').drop(['target'],axis=1).columns

# %% [markdown]
# ### 범주형 변수

# %%
# ---------------------
# 빈도수
# ---------------------
fig, ax = plt.subplots(1,3,figsize=(15,3))
axes=ax.flatten()
for i, feature in enumerate(cat_cols):
    sns.countplot(x=feature,data=df, ax=axes[i])
    axes[i].tick_params(axis='x', rotation=90)

# %%
# ---------------------
# 성공률
# ---------------------
fig, ax = plt.subplots(1,3,figsize=(15,3))
axes=ax.flatten()
for i, feature in enumerate(cat_cols):
    sns.barplot(x=feature, y='target', data=df, ax=axes[i])
    axes[i].tick_params(axis='x', rotation=90)

# %% [markdown]
# ### 수치형 변수

# %%
fig, ax = plt.subplots(3,4,figsize=(15,10))
axes=ax.flatten()
for i, feature in enumerate(num_cols):
    sns.boxplot(x='target', y=feature, data=df, ax=axes[i])
plt.tight_layout()

# %% [markdown]
# ### 정제된 데이터 다운로드

# %%
df.to_csv('data/RocketLaunchDataCompleted2.csv', index=False)
